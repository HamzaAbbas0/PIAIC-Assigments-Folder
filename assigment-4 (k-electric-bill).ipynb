# %% [markdown]
#    # Making the k-electric bill

# %%
def bill_main(monthly_units):
    electric_charges=electricity(monthly_units)
    print("electricity charges of",monthly_units,"units is",electricity(monthly_units))
    
    uniform_charges =uniform(monthly_units)
    print("Uniform charges of ",monthly_units,"units is ",uniform_charges)
    
    fuel_charges = fuel(monthly_units)
    print("fuel charges of ",monthly_units,"units is ",fuel_charges)
    
    sales = sales_tax(monthly_units)
    print("Sales tax charges of ",monthly_units,"units is ",sales)
    
    advance = advance_tax(monthly_units)
    print("Advance tax charges of ",monthly_units,"units is ",advance)

    tv = tv_fee(monthly_units)
    print("tv fees charges of ",monthly_units,"units is ",tv)
    
    total=electric_charges + uniform_charges + fuel_charges + sales + advance +tv 
    print("YOUR TOTAL BILL YOU CAN PAY IS ",total)

def electricity(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=monthly_units *9.43
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=monthly_units *10.29
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=monthly_units *12.55
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=monthly_units *17.38
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=monthly_units *18.84
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=monthly_units *19.76
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=monthly_units *20.40
        return charges
    elif monthly_units>700:
        charges=monthly_units *23.87
        return charges
    else:
        print("Some Things Went Wrong !")

def uniform(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=500
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=800
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=1200
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=1500
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=1800
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=2100
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=2300
        return charges
    elif monthly_units>700:
        charges=2600
        return charges
    else:
        print("Some Things Went Wrong !")

def fuel(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=200
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=400
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=600
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=800
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=1000
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=1200
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=1500
        return charges
    elif monthly_units>700:
        charges=1800
        return charges
    else:
        print("Some Things Went Wrong !")
        
def sales_tax(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=monthly_units +10
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=monthly_units + 20
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=monthly_units +30
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=monthly_units +40
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=monthly_units + 50
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=monthly_units +60
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=monthly_units +70
        return charges
    elif monthly_units>700:
        charges=monthly_units  + 80
        return charges
    else:
        print("Some Things Went Wrong !")
        
def advance_tax(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=10
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=20
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=30
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=40
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=50
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=60
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=70
        return charges
    elif monthly_units>700:
        charges=70
        return charges
    else:
        print("Some Things Went Wrong !")
        
def tv_fee(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=200
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=200
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=200
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=200
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=200
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=200
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=200
        return charges
    elif monthly_units>700:
        charges=200
        return charges
    else:
        print("Some Things Went Wrong !")

monthly_units=int(input("Please Enter You Electricity Units to find Your Electricity Bill : "))

bill_main(monthly_units)
# Out:
# Please Enter You Electricity Units to find Your Electricity Bill : 600
# electricity charges of 600 units is 11856.000000000002
# Uniform charges of  600 units is  2100
# fuel charges of  600 units is  1200
# Sales tax charges of  600 units is  660
# Advance tax charges of  600 units is  60
# tv fees charges of  600 units is  200
# YOUR TOTAL BILL YOU CAN PAY IS  16076.000000000002

# %%
def tv_fee(monthly_units):
    if monthly_units>0 and monthly_units <=100:
        charges=200
        return charges
    elif monthly_units>100 and monthly_units <=200:
        charges=200
        return charges
    elif monthly_units>200 and monthly_units <=300:
        charges=200
        return charges
    elif monthly_units>300 and monthly_units <=400:
        charges=200
        return charges
    elif monthly_units>400 and monthly_units <=500:
        charges=200
        return charges
    elif monthly_units>500 and monthly_units <=600:
        charges=200
        return charges
    elif monthly_units>600 and monthly_units <=700:
        charges=200
        return charges
    elif monthly_units>700:
        charges=200
        return charges
    else:
        print("Some Things Went Wrong !")
tv_fee(300)
# Out:
# 200
